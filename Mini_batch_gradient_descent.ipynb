# %% [markdown]
# <a href="https://colab.research.google.com/github/2023002786/2023002786_/blob/main/Mini_batch_gradient_descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np


x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 6, 8, 10])


w = 0
b = 0
lr = 0.01
epochs = 50
batch_size = 2


for epoch in range(epochs):

    for i in range(0, len(x), batch_size):

        x_batch = x[i : i + batch_size]
        y_batch = y[i : i + batch_size]


        y_pred = w * x_batch + b


        dw = -2 * np.mean(x_batch * (y_batch - y_pred))
        db = -2 * np.mean(y_batch - y_pred)


        w = w - lr * dw
        b = b - lr * db


print("weight :", w)
print("Bias :", b)
